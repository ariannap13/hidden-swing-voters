# %%
# Libraries
import pandas as pd
import os

# %%
# NB raw data is not included in the repository
# for more details, see the paper 
# "ITA-ELECTION-2022: A multi-platform dataset of social media conversations around the 2022 Italian general election", Pierri et al. 2023

# Getting all filenames for each period sorted by date
# - each file contains a list of retweets for a given day
path = '../../data/raw_data/'
preprocessed_path = '../../data/preprocessed_data/'

before_path = os.path.join(path, 'before_campaign')
campaign_path = os.path.join(path, 'electoral_campaign')
after_path = os.path.join(path, 'after_elections')

before_filenames = sorted(os.listdir(before_path))
campaign_filenames = sorted(os.listdir(campaign_path))
after_filenames = sorted(os.listdir(after_path))

# Some info
print('Length of the period before the beginning of the electoral campaign (# of days): ', len(before_filenames))
print('Length of the electoral campaign (# of days): ', len(campaign_filenames))
print('Length of the period after the elections (# of days): ', len(after_filenames))
# Out:
# Length of the period before the beginning of the electoral campaign (# of days):  56
# Length of the electoral campaign (# of days):  31
# Length of the period after the elections (# of days):  26

# %%
# Parsing data
before_data = pd.DataFrame(columns=['source', 'dest', 'text_tweet_id', 'created_at', 'type']) 
print("Created empty DataFrame...")

for name in before_filenames:
    # Loading df
    df = pd.read_csv(os.path.join(before_path, name), sep=',')
    df['source'] = df['source'].astype(int)
    df['dest'] = df['dest'].astype(int)

    _items = df.shape[0]

    # Removing reply tweets
    df = df[df.type == 'retweet']
    _retweets = df.shape[0]

    # Some info
    print(f"{name} - {_retweets} retweets out of {_items} items ({round(_retweets/_items*100, 2)}%)")

    # Adding to the main dataframe
    before_data = pd.concat([before_data, df])

    # Some more info
    current_date = name.split('_')[-1]
    print(f"{current_date} - {before_data.shape[0]} total retweets")
    print()
# Out:
# Created empty DataFrame...
# file_edges_date_2022-07-01 - 8353 retweets out of 36015 items (23.19%)
# 2022-07-01 - 8353 total retweets
#
# file_edges_date_2022-07-02 - 11406 retweets out of 33181 items (34.38%)
# 2022-07-02 - 19759 total retweets
#
# file_edges_date_2022-07-03 - 10987 retweets out of 36299 items (30.27%)
# 2022-07-03 - 30746 total retweets
#
# file_edges_date_2022-07-04 - 9472 retweets out of 29158 items (32.49%)
# 2022-07-04 - 40218 total retweets
#
# file_edges_date_2022-07-05 - 9097 retweets out of 26164 items (34.77%)
# 2022-07-05 - 49315 total retweets
#
# file_edges_date_2022-07-06 - 12577 retweets out of 34584 items (36.37%)
# 2022-07-06 - 61892 total retweets
#
# file_edges_date_2022-07-07 - 11908 retweets out of 35238 items (33.79%)
# 2022-07-07 - 73800 total retweets
#
# file_edges_date_2022-07-08 - 9003 retweets out of 33122 items (27.18%)
# 2022-07-08 - 82803 total retweets
#
# file_edges_date_2022-07-09 - 10037 retweets out of 32464 items (30.92%)
# 2022-07-09 - 92840 total retweets
#
# file_edges_date_2022-07-10 - 9889 retweets out of 30133 items (32.82%)
# 2022-07-10 - 102729 total retweets
#
# file_edges_date_2022-07-11 - 15373 retweets out of 38376 items (40.06%)
# 2022-07-11 - 118102 total retweets
#
# file_edges_date_2022-07-12 - 16480 retweets out of 44310 items (37.19%)
# 2022-07-12 - 134582 total retweets
#
# file_edges_date_2022-07-13 - 19713 retweets out of 50533 items (39.01%)
# 2022-07-13 - 154295 total retweets
#
# file_edges_date_2022-07-14 - 32341 retweets out of 93290 items (34.67%)
# 2022-07-14 - 186636 total retweets
#
# file_edges_date_2022-07-15 - 23124 retweets out of 67893 items (34.06%)
# 2022-07-15 - 209760 total retweets
#
# file_edges_date_2022-07-16 - 18064 retweets out of 61555 items (29.35%)
# 2022-07-16 - 227824 total retweets
#
# file_edges_date_2022-07-17 - 25423 retweets out of 69105 items (36.79%)
# 2022-07-17 - 253247 total retweets
#
# file_edges_date_2022-07-18 - 26835 retweets out of 69006 items (38.89%)
# 2022-07-18 - 280082 total retweets
#
# file_edges_date_2022-07-19 - 27804 retweets out of 68926 items (40.34%)
# 2022-07-19 - 307886 total retweets
#
# file_edges_date_2022-07-20 - 64943 retweets out of 153349 items (42.35%)
# 2022-07-20 - 372829 total retweets
#
# file_edges_date_2022-07-21 - 57600 retweets out of 162330 items (35.48%)
# 2022-07-21 - 430429 total retweets
#
# file_edges_date_2022-07-22 - 47464 retweets out of 132849 items (35.73%)
# 2022-07-22 - 477893 total retweets
#
# file_edges_date_2022-07-23 - 28714 retweets out of 87925 items (32.66%)
# 2022-07-23 - 506607 total retweets
#
# file_edges_date_2022-07-24 - 29922 retweets out of 98843 items (30.27%)
# 2022-07-24 - 536529 total retweets
#
# file_edges_date_2022-07-25 - 33325 retweets out of 98375 items (33.88%)
# 2022-07-25 - 569854 total retweets
#
# file_edges_date_2022-07-26 - 31071 retweets out of 96959 items (32.05%)
# 2022-07-26 - 600925 total retweets
#
# file_edges_date_2022-07-27 - 30737 retweets out of 95470 items (32.2%)
# 2022-07-27 - 631662 total retweets
#
# file_edges_date_2022-07-28 - 32492 retweets out of 101004 items (32.17%)
# 2022-07-28 - 664154 total retweets
#
# file_edges_date_2022-07-29 - 32534 retweets out of 99301 items (32.76%)
# 2022-07-29 - 696688 total retweets
#
# file_edges_date_2022-07-30 - 28229 retweets out of 95937 items (29.42%)
# 2022-07-30 - 724917 total retweets
#
# file_edges_date_2022-07-31 - 31794 retweets out of 99729 items (31.88%)
# 2022-07-31 - 756711 total retweets
#
# file_edges_date_2022-08-01 - 25799 retweets out of 89750 items (28.75%)
# 2022-08-01 - 782510 total retweets
#
# file_edges_date_2022-08-02 - 33453 retweets out of 116766 items (28.65%)
# 2022-08-02 - 815963 total retweets
#
# file_edges_date_2022-08-03 - 33633 retweets out of 118435 items (28.4%)
# 2022-08-03 - 849596 total retweets
#
# file_edges_date_2022-08-04 - 30044 retweets out of 86463 items (34.75%)
# 2022-08-04 - 879640 total retweets
#
# file_edges_date_2022-08-05 - 36949 retweets out of 109917 items (33.62%)
# 2022-08-05 - 916589 total retweets
#
# file_edges_date_2022-08-06 - 34671 retweets out of 108512 items (31.95%)
# 2022-08-06 - 951260 total retweets
#
# file_edges_date_2022-08-07 - 39018 retweets out of 149412 items (26.11%)
# 2022-08-07 - 990278 total retweets
#
# file_edges_date_2022-08-08 - 29344 retweets out of 107364 items (27.33%)
# 2022-08-08 - 1019622 total retweets
#
# file_edges_date_2022-08-09 - 27753 retweets out of 91671 items (30.27%)
# 2022-08-09 - 1047375 total retweets
#
# file_edges_date_2022-08-10 - 28777 retweets out of 99593 items (28.89%)
# 2022-08-10 - 1076152 total retweets
#
# file_edges_date_2022-08-11 - 37488 retweets out of 116819 items (32.09%)
# 2022-08-11 - 1113640 total retweets
#
# file_edges_date_2022-08-12 - 38120 retweets out of 115188 items (33.09%)
# 2022-08-12 - 1151760 total retweets
#
# file_edges_date_2022-08-13 - 31777 retweets out of 90832 items (34.98%)
# 2022-08-13 - 1183537 total retweets
#
# file_edges_date_2022-08-14 - 31087 retweets out of 91128 items (34.11%)
# 2022-08-14 - 1214624 total retweets
#
# file_edges_date_2022-08-15 - 29653 retweets out of 90660 items (32.71%)
# 2022-08-15 - 1244277 total retweets
#
# file_edges_date_2022-08-16 - 33579 retweets out of 97673 items (34.38%)
# 2022-08-16 - 1277856 total retweets
#
# file_edges_date_2022-08-17 - 35152 retweets out of 105881 items (33.2%)
# 2022-08-17 - 1313008 total retweets
#
# file_edges_date_2022-08-18 - 35999 retweets out of 104362 items (34.49%)
# 2022-08-18 - 1349007 total retweets
#
# file_edges_date_2022-08-19 - 37400 retweets out of 111602 items (33.51%)
# 2022-08-19 - 1386407 total retweets
#
# file_edges_date_2022-08-20 - 35722 retweets out of 101665 items (35.14%)
# 2022-08-20 - 1422129 total retweets
#
# file_edges_date_2022-08-21 - 33626 retweets out of 96378 items (34.89%)
# 2022-08-21 - 1455755 total retweets
#
# file_edges_date_2022-08-22 - 41924 retweets out of 127889 items (32.78%)
# 2022-08-22 - 1497679 total retweets
#
# file_edges_date_2022-08-23 - 41746 retweets out of 115907 items (36.02%)
# 2022-08-23 - 1539425 total retweets
#
# file_edges_date_2022-08-24 - 64707 retweets out of 138317 items (46.78%)
# 2022-08-24 - 1604132 total retweets
#
# file_edges_date_2022-08-25 - 44130 retweets out of 119355 items (36.97%)
# 2022-08-25 - 1648262 total retweets

# %%
# Visualizing it
before_data.head()
# Out:
#                 source                 dest        text_tweet_id  \
# 2  1082281620546179072           2983707267  1542932295828381696
# 3  1063507457589370880   980562312984780800  1542930963071746048
# 4            337372191   977383349235961728  1542847308135632896
# 5  1240214959776239616            432516884  1542935003264614400
# 7            390427246  1300916262369984512  1542948182598062080
#
#                   created_at     type
# 2  2022-07-01 23:59:34+00:00  retweet
# 3  2022-07-01 23:59:13+00:00  retweet
# 4  2022-07-01 23:59:03+00:00  retweet
# 5  2022-07-01 23:59:01+00:00  retweet
# 7  2022-07-01 23:58:40+00:00  retweet

# %%
# Exporting it
before_data.to_csv(os.path.join(preprocessed_path, 'before_campaign.csv'), index=False)
print("Done!")
# Out:
# Done!

# %%
# Parsing data
campaign_data = pd.DataFrame(columns=['source', 'dest', 'text_tweet_id', 'created_at', 'type'])
print("Created empty DataFrame...")

for name in campaign_filenames[1:]:
    # Loading df
    df = pd.read_csv(os.path.join(campaign_path, name), sep=',') 

    df['source'] = df['source'].astype(int)
    df['dest'] = df['dest'].astype(int)

    _items = df.shape[0]

    # Removing reply tweets
    df = df[df.type == 'retweet']
    _retweets = df.shape[0]

    # Some info
    print(f"{name} - {_retweets} retweets out of {_items} items ({round(_retweets/_items*100, 2)}%)")

    # Adding to the main dataframe
    campaign_data = pd.concat([campaign_data, df])

    # Some more info
    current_date = name.split('_')[-1]
    print(f"{current_date} - {campaign_data.shape[0]} total retweets")
    print()
# Out:
# Created empty DataFrame...
# file_edges_date_2022-08-26 - 32533 retweets out of 105470 items (30.85%)
# 2022-08-26 - 2556559 total retweets
#
# file_edges_date_2022-08-27 - 29990 retweets out of 96239 items (31.16%)
# 2022-08-27 - 2556559 total retweets
#
# file_edges_date_2022-08-28 - 31810 retweets out of 94358 items (33.71%)
# 2022-08-28 - 2556559 total retweets
#
# file_edges_date_2022-08-29 - 27805 retweets out of 91124 items (30.51%)
# 2022-08-29 - 2556559 total retweets
#
# file_edges_date_2022-08-30 - 24201 retweets out of 89639 items (27.0%)
# 2022-08-30 - 2556559 total retweets
#
# file_edges_date_2022-08-31 - 25680 retweets out of 82285 items (31.21%)
# 2022-08-31 - 2556559 total retweets
#
# file_edges_date_2022-09-01 - 23994 retweets out of 80066 items (29.97%)
# 2022-09-01 - 2556559 total retweets
#
# file_edges_date_2022-09-02 - 88495 retweets out of 430691 items (20.55%)
# 2022-09-02 - 2556559 total retweets
#
# file_edges_date_2022-09-03 - 100309 retweets out of 491989 items (20.39%)
# 2022-09-03 - 2556559 total retweets
#
# file_edges_date_2022-09-04 - 94296 retweets out of 471033 items (20.02%)
# 2022-09-04 - 2556559 total retweets
#
# file_edges_date_2022-09-05 - 86208 retweets out of 410951 items (20.98%)
# 2022-09-05 - 2556559 total retweets
#
# file_edges_date_2022-09-06 - 94232 retweets out of 435502 items (21.64%)
# 2022-09-06 - 2556559 total retweets
#
# file_edges_date_2022-09-07 - 92788 retweets out of 429570 items (21.6%)
# 2022-09-07 - 2556559 total retweets
#
# file_edges_date_2022-09-08 - 86855 retweets out of 398585 items (21.79%)
# 2022-09-08 - 2556559 total retweets
#
# file_edges_date_2022-09-09 - 92245 retweets out of 418714 items (22.03%)
# 2022-09-09 - 2556559 total retweets
#
# file_edges_date_2022-09-10 - 84409 retweets out of 374094 items (22.56%)
# 2022-09-10 - 2556559 total retweets
#
# file_edges_date_2022-09-11 - 89547 retweets out of 374379 items (23.92%)
# 2022-09-11 - 2556559 total retweets
#
# file_edges_date_2022-09-12 - 87237 retweets out of 371210 items (23.5%)
# 2022-09-12 - 2556559 total retweets
#
# file_edges_date_2022-09-13 - 96784 retweets out of 427452 items (22.64%)
# 2022-09-13 - 2556559 total retweets
#
# file_edges_date_2022-09-14 - 98613 retweets out of 425477 items (23.18%)
# 2022-09-14 - 2556559 total retweets
#
# file_edges_date_2022-09-15 - 93453 retweets out of 392828 items (23.79%)
# 2022-09-15 - 2556559 total retweets
#
# file_edges_date_2022-09-16 - 108852 retweets out of 451711 items (24.1%)
# 2022-09-16 - 2556559 total retweets
#
# file_edges_date_2022-09-17 - 116820 retweets out of 474075 items (24.64%)
# 2022-09-17 - 2556559 total retweets
#
# file_edges_date_2022-09-18 - 116319 retweets out of 512281 items (22.71%)
# 2022-09-18 - 2556559 total retweets
#
# file_edges_date_2022-09-19 - 94419 retweets out of 419098 items (22.53%)
# 2022-09-19 - 2556559 total retweets
#
# file_edges_date_2022-09-20 - 116472 retweets out of 454570 items (25.62%)
# 2022-09-20 - 2556559 total retweets
#
# file_edges_date_2022-09-21 - 123966 retweets out of 489649 items (25.32%)
# 2022-09-21 - 2556559 total retweets
#
# file_edges_date_2022-09-22 - 111718 retweets out of 450023 items (24.82%)
# 2022-09-22 - 2556559 total retweets
#
# file_edges_date_2022-09-23 - 159086 retweets out of 626945 items (25.37%)
# 2022-09-23 - 2556559 total retweets
#
# file_edges_date_2022-09-24 - 127423 retweets out of 515595 items (24.71%)
# 2022-09-24 - 2556559 total retweets

# %%
# Visualizing it
campaign_data.head(10)
# Out:
#                  source                 dest        text_tweet_id  \
# 0              59101703           1557514573  1563252095368605696
# 1   1480682060767506432  1096360092809810048  1563231317185085440
# 2   1363801884658696192   912281497314447232  1562718175103700992
# 5   1554231181687808000            171981193  1563129867235119104
# 6   1056590361722867712  1296055260394532864  1562466497582497792
# 19            426112917  1016249336903159808  1563300827200045056
# 20            304312411            497995758  1563078628208148480
# 24   810145644706926592            532238684  1563242165261996032
# 28            392987772             13294452  1563219874972725248
# 32  1470866013457686528  1220673282191523840  1563087881325137920
#
#                    created_at     type  Unnamed: 0
# 0   2022-08-26 23:59:59+00:00  retweet         NaN
# 1   2022-08-26 23:59:56+00:00  retweet         NaN
# 2   2022-08-26 23:59:51+00:00  retweet         NaN
# 5   2022-08-26 23:59:37+00:00  retweet         NaN
# 6   2022-08-26 23:59:34+00:00  retweet         NaN
# 19  2022-08-26 23:58:59+00:00  retweet         NaN
# 20  2022-08-26 23:58:59+00:00  retweet         NaN
# 24  2022-08-26 23:58:53+00:00  retweet         NaN
# 28  2022-08-26 23:58:37+00:00  retweet         NaN
# 32  2022-08-26 23:58:21+00:00  retweet         NaN

# %%
# drop unnamed column
campaign_data = campaign_data.drop(columns=['Unnamed: 0'])

# %%
# Exporting it
campaign_data.to_csv(os.path.join(preprocessed_path, 'electoral_campaign.csv'), index=False)

# %%
# Parsing data
after_data = pd.DataFrame(columns=['source', 'dest', 'text_tweet_id', 'created_at', 'type'])
print("Created empty DataFrame...")

for name in after_filenames:
    # Loading df
    df = pd.read_csv(os.path.join(after_path, name), sep=',') 
    _items = df.shape[0]

    # Removing reply tweets
    df = df[df.type == 'retweet']
    _retweets = df.shape[0]

    df['source'] = df['source'].astype(int)
    df['dest'] = df['dest'].astype(int)

    # Some info
    print(f"{name} - {_retweets} retweets out of {_items} items ({round(_retweets/_items*100, 2)}%)")

    # Adding to the main dataframe
    after_data = pd.concat([after_data, df])

    # Some more info
    current_date = name.split('_')[-1]
    print(f"{current_date} - {after_data.shape[0]} total retweets")
    print()
# Out:
# Created empty DataFrame...
# file_edges_date_2022-09-25 - 202922 retweets out of 659046 items (30.79%)
# 2022-09-25 - 202922 total retweets
#
# file_edges_date_2022-09-26 - 415623 retweets out of 1390815 items (29.88%)
# 2022-09-26 - 618545 total retweets
#
# file_edges_date_2022-09-27 - 145686 retweets out of 627834 items (23.2%)
# 2022-09-27 - 764231 total retweets
#
# file_edges_date_2022-09-28 - 105431 retweets out of 480108 items (21.96%)
# 2022-09-28 - 869662 total retweets
#
# file_edges_date_2022-09-29 - 85880 retweets out of 401740 items (21.38%)
# 2022-09-29 - 955542 total retweets
#
# file_edges_date_2022-09-30 - 72529 retweets out of 357819 items (20.27%)
# 2022-09-30 - 1028071 total retweets
#
# file_edges_date_2022-10-01 - 53271 retweets out of 264755 items (20.12%)
# 2022-10-01 - 1081342 total retweets
#
# file_edges_date_2022-10-02 - 47609 retweets out of 222799 items (21.37%)
# 2022-10-02 - 1128951 total retweets
#
# file_edges_date_2022-10-03 - 48408 retweets out of 214751 items (22.54%)
# 2022-10-03 - 1177359 total retweets
#
# file_edges_date_2022-10-04 - 48201 retweets out of 239150 items (20.16%)
# 2022-10-04 - 1225560 total retweets
#
# file_edges_date_2022-10-05 - 52056 retweets out of 234088 items (22.24%)
# 2022-10-05 - 1277616 total retweets
#
# file_edges_date_2022-10-06 - 52276 retweets out of 243106 items (21.5%)
# 2022-10-06 - 1329892 total retweets
#
# file_edges_date_2022-10-07 - 48092 retweets out of 219596 items (21.9%)
# 2022-10-07 - 1377984 total retweets
#
# file_edges_date_2022-10-08 - 40012 retweets out of 184238 items (21.72%)
# 2022-10-08 - 1417996 total retweets
#
# file_edges_date_2022-10-09 - 40782 retweets out of 186743 items (21.84%)
# 2022-10-09 - 1458778 total retweets
#
# file_edges_date_2022-10-10 - 42729 retweets out of 205360 items (20.81%)
# 2022-10-10 - 1501507 total retweets
#
# file_edges_date_2022-10-11 - 46270 retweets out of 210058 items (22.03%)
# 2022-10-11 - 1547777 total retweets
#
# file_edges_date_2022-10-12 - 42371 retweets out of 189378 items (22.37%)
# 2022-10-12 - 1590148 total retweets
#
# file_edges_date_2022-10-13 - 72610 retweets out of 331248 items (21.92%)
# 2022-10-13 - 1662758 total retweets
#
# file_edges_date_2022-10-14 - 74047 retweets out of 361714 items (20.47%)
# 2022-10-14 - 1736805 total retweets
#
# file_edges_date_2022-10-15 - 65440 retweets out of 362946 items (18.03%)
# 2022-10-15 - 1802245 total retweets
#
# file_edges_date_2022-10-16 - 51989 retweets out of 273947 items (18.98%)
# 2022-10-16 - 1854234 total retweets
#
# file_edges_date_2022-10-17 - 44520 retweets out of 219543 items (20.28%)
# 2022-10-17 - 1898754 total retweets
#
# file_edges_date_2022-10-18 - 58714 retweets out of 278146 items (21.11%)
# 2022-10-18 - 1957468 total retweets
#
# file_edges_date_2022-10-19 - 84442 retweets out of 362594 items (23.29%)
# 2022-10-19 - 2041910 total retweets
#
# file_edges_date_2022-10-20 - 28373 retweets out of 112982 items (25.11%)
# 2022-10-20 - 2070283 total retweets

# %%
# Visualizing it
after_data.head()
# Out:
#                  source                 dest        text_tweet_id  \
# 2   1547691038034120705  1460611925906181888  1573654988177432576
# 4             908147456            828717014  1573434419658248199
# 6             379926998           2326660325  1573758541109907456
# 8   1498444048079675398            873255372  1573593048495407104
# 10            191522922  1244928423224586240  1573697306930696195
#
#                    created_at     type  Unnamed: 0
# 2   2022-09-24 21:59:55+00:00  retweet         2.0
# 4   2022-09-24 21:59:56+00:00  retweet         4.0
# 6   2022-09-24 21:59:57+00:00  retweet         6.0
# 8   2022-09-24 21:59:58+00:00  retweet         8.0
# 10  2022-09-24 21:59:58+00:00  retweet        10.0

# %%
# drop unnamed column
after_data = after_data.drop(columns=['Unnamed: 0'])

# %%
# Visualizing it
after_data.head()
# Out:
#                  source                 dest        text_tweet_id  \
# 2   1547691038034120705  1460611925906181888  1573654988177432576
# 4             908147456            828717014  1573434419658248199
# 6             379926998           2326660325  1573758541109907456
# 8   1498444048079675398            873255372  1573593048495407104
# 10            191522922  1244928423224586240  1573697306930696195
#
#                    created_at     type
# 2   2022-09-24 21:59:55+00:00  retweet
# 4   2022-09-24 21:59:56+00:00  retweet
# 6   2022-09-24 21:59:57+00:00  retweet
# 8   2022-09-24 21:59:58+00:00  retweet
# 10  2022-09-24 21:59:58+00:00  retweet

# %%
# Exporting it
after_data.to_csv(os.path.join(preprocessed_path, 'after_elections.csv'), index=False)
